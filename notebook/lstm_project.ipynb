# %% [markdown]
# # AIRLINE LSTM Project
# Data analysis, preprocessing, training, and model saving.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
df = pd.read_csv("../data/AirPassengers.csv")

df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
# Data analysis
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB
# None
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000
# Month          0
# #Passengers    0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.plot(df["#Passengers"])
plt.title("Airline Passengers Over Time")
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.show()

# %%
scaler = MinMaxScaler()

data = scaler.fit_transform(
    df[["#Passengers"]]
)

joblib.dump(
    scaler,
    "../models/scaler.pkl"
)
# Out:
# ['../models/scaler.pkl']

# %%
X = []
y = []

window_size = 12

for i in range(window_size, len(data)):
    X.append(
        data[i-window_size:i, 0]
    )

    y.append(
        data[i, 0]
    )

X = np.array(X)
y = np.array(y)

X = X.reshape(
    X.shape[0],
    X.shape[1],
    1
)

print(X.shape)
print(y.shape)
# Out:
# (132, 12, 1)
# (132,)

# %%
split = int(len(X)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
model = Sequential()

model.add(
    LSTM(
        units=64,
        return_sequences=True,
        input_shape=(12, 1)
    )
)

model.add(
    Dropout(0.2)
)

model.add(
    LSTM(
        units=32
    )
)

model.add(
    Dropout(0.2)
)

model.add(
    Dense(1)
)

model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

model.summary()
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# c:\Users\harsh\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 12, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0544 - mae: 0.1722 - val_loss: 0.0220 - val_mae: 0.1278
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0159 - mae: 0.1040 - val_loss: 0.0582 - val_mae: 0.1919
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0121 - mae: 0.0772 - val_loss: 0.0218 - val_mae: 0.1232
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0096 - mae: 0.0811 - val_loss: 0.0309 - val_mae: 0.1262
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0096 - mae: 0.0706 - val_loss: 0.0217 - val_mae: 0.1220
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0102 - mae: 0.0732 - val_loss: 0.0214 - val_mae: 0.1171
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104 - mae: 0.0751 - val_loss: 0.0247 - val_mae: 0.1161
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0092 - mae: 0.0676 - val_loss: 0.0226 - val_mae: 0.1308
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - mae: 0.0612 - val_loss: 0.0209 - val_mae: 0.1181
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089 - mae: 0.0702 - val_loss: 0.0222 - val_mae: 0.1124
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - mae: 0.0691 - val_loss: 0.0224 - val_mae: 0.1123
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mae: 0.0643 - val_loss: 0.0202 - val_mae: 0.1159
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074 - mae: 0.0629 - val_loss: 0.0201 - val_mae: 0.1173
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0085 - mae: 0.0694 - val_loss: 0.0200 - val_mae: 0.1124
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - mae: 0.0691 - val_loss: 0.0215 - val_mae: 0.1098
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - mae: 0.0616 - val_loss: 0.0203 - val_mae: 0.1092
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0067 - mae: 0.0600 - val_loss: 0.0200 - val_mae: 0.1210
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0193 - val_mae: 0.1095
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0082 - mae: 0.0643 - val_loss: 0.0191 - val_mae: 0.1157
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0100 - mae: 0.0733 - val_loss: 0.0208 - val_mae: 0.1066
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0095 - mae: 0.0731 - val_loss: 0.0301 - val_mae: 0.1241
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - mae: 0.0667 - val_loss: 0.0235 - val_mae: 0.1097
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089 - mae: 0.0675 - val_loss: 0.0203 - val_mae: 0.1056
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0079 - mae: 0.0677 - val_loss: 0.0185 - val_mae: 0.1078
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0077 - mae: 0.0685 - val_loss: 0.0239 - val_mae: 0.1095
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - mae: 0.0671 - val_loss: 0.0191 - val_mae: 0.1043
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - mae: 0.0598 - val_loss: 0.0183 - val_mae: 0.1018
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0075 - mae: 0.0676 - val_loss: 0.0176 - val_mae: 0.1044
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0110 - mae: 0.0787 - val_loss: 0.0337 - val_mae: 0.1345
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - mae: 0.0673 - val_loss: 0.0309 - val_mae: 0.1274
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0096 - mae: 0.0729 - val_loss: 0.0175 - val_mae: 0.1068
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - mae: 0.0596 - val_loss: 0.0223 - val_mae: 0.1056
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mae: 0.0638 - val_loss: 0.0239 - val_mae: 0.1096
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0090 - mae: 0.0667 - val_loss: 0.0190 - val_mae: 0.1225
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078 - mae: 0.0680 - val_loss: 0.0197 - val_mae: 0.1000
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072 - mae: 0.0629 - val_loss: 0.0177 - val_mae: 0.0974
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - mae: 0.0586 - val_loss: 0.0163 - val_mae: 0.1106
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - mae: 0.0693 - val_loss: 0.0300 - val_mae: 0.1269
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - mae: 0.0632 - val_loss: 0.0189 - val_mae: 0.0972
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - mae: 0.0589 - val_loss: 0.0164 - val_mae: 0.0924
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - mae: 0.0590 - val_loss: 0.0166 - val_mae: 0.0920
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mae: 0.0601 - val_loss: 0.0140 - val_mae: 0.0891
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mae: 0.0617 - val_loss: 0.0163 - val_mae: 0.0902
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - mae: 0.0610 - val_loss: 0.0367 - val_mae: 0.1501
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - mae: 0.0620 - val_loss: 0.0135 - val_mae: 0.0915
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - mae: 0.0667 - val_loss: 0.0179 - val_mae: 0.0954
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - mae: 0.0705 - val_loss: 0.0174 - val_mae: 0.0926
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - mae: 0.0576 - val_loss: 0.0156 - val_mae: 0.0888
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0215 - val_mae: 0.1050
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - mae: 0.0577 - val_loss: 0.0209 - val_mae: 0.1046
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - mae: 0.0522 - val_loss: 0.0123 - val_mae: 0.0974
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054 - mae: 0.0550 - val_loss: 0.0122 - val_mae: 0.0806
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0043 - mae: 0.0485 - val_loss: 0.0193 - val_mae: 0.1029
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - mae: 0.0485 - val_loss: 0.0157 - val_mae: 0.0931
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - mae: 0.0560 - val_loss: 0.0334 - val_mae: 0.1538
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - mae: 0.0523 - val_loss: 0.0094 - val_mae: 0.0811
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072 - mae: 0.0620 - val_loss: 0.0291 - val_mae: 0.1470
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0081 - mae: 0.0654 - val_loss: 0.0142 - val_mae: 0.0885
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - mae: 0.0599 - val_loss: 0.0148 - val_mae: 0.0912
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - mae: 0.0518 - val_loss: 0.0063 - val_mae: 0.0619
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - mae: 0.0532 - val_loss: 0.0128 - val_mae: 0.0879
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - mae: 0.0493 - val_loss: 0.0340 - val_mae: 0.1623
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046 - mae: 0.0498 - val_loss: 0.0064 - val_mae: 0.0646
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - mae: 0.0442 - val_loss: 0.0247 - val_mae: 0.1400
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0046 - val_mae: 0.0547
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - mae: 0.0473 - val_loss: 0.0366 - val_mae: 0.1693
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - mae: 0.0453 - val_loss: 0.0181 - val_mae: 0.1137
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - mae: 0.0532 - val_loss: 0.0109 - val_mae: 0.0818
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 0.0185 - val_mae: 0.1143
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - mae: 0.0483 - val_loss: 0.0074 - val_mae: 0.0691
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - mae: 0.0443 - val_loss: 0.0301 - val_mae: 0.1524
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - mae: 0.0470 - val_loss: 0.0118 - val_mae: 0.0885
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0410 - val_loss: 0.0344 - val_mae: 0.1612
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - mae: 0.0442 - val_loss: 0.0218 - val_mae: 0.1298
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - mae: 0.0456 - val_loss: 0.0193 - val_mae: 0.1236
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0162 - mae: 0.0930 - val_loss: 0.0281 - val_mae: 0.1319
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - mae: 0.0585 - val_loss: 0.0141 - val_mae: 0.0917
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058 - mae: 0.0568 - val_loss: 0.0159 - val_mae: 0.0908
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0055 - mae: 0.0555 - val_loss: 0.0131 - val_mae: 0.0831
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - mae: 0.0561 - val_loss: 0.0129 - val_mae: 0.0818
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050 - mae: 0.0543 - val_loss: 0.0148 - val_mae: 0.0901
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0047 - mae: 0.0522 - val_loss: 0.0100 - val_mae: 0.0746
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050 - mae: 0.0540 - val_loss: 0.0099 - val_mae: 0.0753
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mae: 0.0464 - val_loss: 0.0089 - val_mae: 0.0726
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0043 - mae: 0.0546 - val_loss: 0.0205 - val_mae: 0.1197
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 0.0207 - val_mae: 0.1203
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - mae: 0.0392 - val_loss: 0.0118 - val_mae: 0.0852
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0403 - val_loss: 0.0295 - val_mae: 0.1472
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0451 - val_loss: 0.0119 - val_mae: 0.0860
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - mae: 0.0433 - val_loss: 0.0146 - val_mae: 0.0991
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - mae: 0.0435 - val_loss: 0.0139 - val_mae: 0.0990
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0391 - val_loss: 0.0120 - val_mae: 0.0883
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0375 - val_loss: 0.0291 - val_mae: 0.1480
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0425 - val_loss: 0.0226 - val_mae: 0.1269
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0376 - val_loss: 0.0144 - val_mae: 0.0960
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0385 - val_loss: 0.0185 - val_mae: 0.1157
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 0.0106 - val_mae: 0.0846
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0383 - val_loss: 0.0093 - val_mae: 0.0769
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0386 - val_loss: 0.0155 - val_mae: 0.1020
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0363 - val_loss: 0.0223 - val_mae: 0.1261

# %%
predictions = model.predict(X_test)

predictions = scaler.inverse_transform(predictions)

actual = scaler.inverse_transform(
    y_test.reshape(-1,1)
)

from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(
    mean_squared_error(
        actual,
        predictions
    )
)

print("RMSE:", rmse)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# RMSE: 77.3184297363522

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("LSTM Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model.save(
    "../models/airline_lstm.keras"
)
print("Model Saved")
# Out:
# Model Saved
